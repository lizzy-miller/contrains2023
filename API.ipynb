# %%
import numpy as np
import pandas as pd
import requests 
import os 
import json

# %%
congressapi = os.getenv('congressapi')
opensecretsapi = os.getenv('opensecretsapi')

# %% [markdown]
# ## Congress Bills API for the 118th Congress

# %%
root = 'https://api.congress.gov/v3'
congress = '118'
endpoint = f'/bill/{congress}'

# %%
parameters = {'format': 'json',
             'offset': 0,
             'limit': 250,
             'sort': 'updateDate+desc',
             'api_key': congressapi}

# %%
r = requests.get('https://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']

# %%
headers = {'User-Agent': useragent,
          'From': 'zrc3hc@virginia.edu'}

# %%
r = requests.get(root + endpoint, 
                params = parameters, 
                headers = headers)

# %%
r
# Out:
# <Response [200]>

# %%
myjson = json.loads(r.text)

# %%
myjson['bills'][0]['number']
# Out:
# '4367'

# %%
#[x['number'] for x in myjson['bills']]

# %%
with open('bills.json', 'w') as f:
    json.dump(myjson, f)

# %%
billsdf = pd.json_normalize(myjson, 
                           record_path = ['bills'])

# %%
billsdf
# Out:
#      congress number originChamber originChamberCode  \
# 0         118   4367         House                 H
# 1         118    730         House                 H
# 2         118    377        Senate                 S
# 3         118    375        Senate                 S
# 4         118    374        Senate                 S
# ..        ...    ...           ...               ...
# 245       118   5157         House                 H
# 246       118   5015         House                 H
# 247       118   4943         House                 H
# 248       118   4920         House                 H
# 249       118   4239         House                 H
#
#                                                  title  type  updateDate  \
# 0    Department of Homeland Security Appropriations...    HR  2023-09-28
# 1    Providing for consideration of the bill (H.R. ...  HRES  2023-09-28
# 2    A resolution recognizing Hispanic Restaurant W...  SRES  2023-09-28
# 3    A resolution supporting the designation of Sep...  SRES  2023-09-28
# 4    A resolution designating September 2023 as "Na...  SRES  2023-09-28
# ..                                                 ...   ...         ...
# 245  To amend the Cooperative Forestry Assistance A...    HR  2023-09-26
# 246  Seedlings for Sustainable Habitat Restoration ...    HR  2023-09-26
# 247  Enabling Farmers to Benefit from Processing Nu...    HR  2023-09-26
# 248             Responsible Wildland Fire Recovery Act    HR  2023-09-26
# 249                  Rebuild Rural America Act of 2023    HR  2023-09-26
#
#     updateDateIncludingText  \
# 0      2023-09-28T20:11:12Z
# 1      2023-09-28T20:11:12Z
# 2      2023-09-28T19:28:42Z
# 3      2023-09-28T19:28:42Z
# 4      2023-09-28T19:28:42Z
# ..                      ...
# 245    2023-09-26T07:13:59Z
# 246    2023-09-26T07:13:59Z
# 247    2023-09-26T07:13:59Z
# 248    2023-09-26T07:13:58Z
# 249    2023-09-26T07:13:58Z
#
#                                                    url  \
# 0    https://api.congress.gov/v3/bill/118/hr/4367?f...
# 1    https://api.congress.gov/v3/bill/118/hres/730?...
# 2    https://api.congress.gov/v3/bill/118/sres/377?...
# 3    https://api.congress.gov/v3/bill/118/sres/375?...
# 4    https://api.congress.gov/v3/bill/118/sres/374?...
# ..                                                 ...
# 245  https://api.congress.gov/v3/bill/118/hr/5157?f...
# 246  https://api.congress.gov/v3/bill/118/hr/5015?f...
# 247  https://api.congress.gov/v3/bill/118/hr/4943?f...
# 248  https://api.congress.gov/v3/bill/118/hr/4920?f...
# 249  https://api.congress.gov/v3/bill/118/hr/4239?f...
#
#     latestAction.actionDate latestAction.actionTime  \
# 0                2023-09-28                00:48:14
# 1                2023-09-28                     NaN
# 2                2023-09-27                     NaN
# 3                2023-09-27                     NaN
# 4                2023-09-27                     NaN
# ..                      ...                     ...
# 245              2023-09-25                     NaN
# 246              2023-09-25                     NaN
# 247              2023-09-25                     NaN
# 248              2023-09-25                     NaN
# 249              2023-09-25                     NaN
#
#                                      latestAction.text
# 0    Committee of the Whole House on the state of t...
# 1       Placed on the House Calendar, Calendar No. 39.
# 2    Submitted in the Senate, considered, and agree...
# 3    Submitted in the Senate, considered, and agree...
# 4    Submitted in the Senate, considered, and agree...
# ..                                                 ...
# 245          Referred to the Subcommittee on Forestry.
# 246          Referred to the Subcommittee on Forestry.
# 247  Referred to the Subcommittee on Nutrition, For...
# 248          Referred to the Subcommittee on Forestry.
# 249  Referred to the Subcommittee on Commodity Mark...
#
# [250 rows x 12 columns]

# %%
root = 'http://www.opensecrets.org/api/'
parameters = {'method': 'getLegislators',
             'apikey': opensecretsapi,
             'id': 'VA', 
             'output': 'json'}

# %%
r = requests.get(root, params = parameters, headers=headers)
r
# Out:
# <Response [200]>

# %%
myjson = json.loads(r.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 myjson = json.loads(r.text)
#
# File /usr/local/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/local/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/local/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
root = 'https://api.congress.gov/v3'
congress = '118'
bill_type = 'hr'
endpoint = f'/bill/{congress}/{bill_type}'

r = requests.get('https://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']
headers = {'User-Agent': useragent,
              'From': 'zrc3hc@virginia.edu'}

house_bills = []
for i in range(0, 1001, 250):
    parameters = {'format': 'json',
                 'offset': i,
                 'limit': 250,
                 'sort': 'updateDate+desc',
                 'api_key': congressapi
                 }
    r = requests.get(root + endpoint, params = parameters, headers = headers)
    myjson = json.loads(r.text)
    bills = myjson['bills']
    house_bills.append(bills)

# %%
df1 = pd.DataFrame.from_dict(house_bills[0])
df2 = pd.DataFrame.from_dict(house_bills[1])
df3 = pd.DataFrame.from_dict(house_bills[2])
df4 = pd.DataFrame.from_dict(house_bills[3])
df5 = pd.DataFrame.from_dict(house_bills[4])
frames = [df1, df2, df3, df4, df5]
house_bills = pd.concat(frames, ignore_index = True)

# %%
house_bills
# Out:
#       congress                                       latestAction number  \
# 0          118  {'actionDate': '2023-10-11', 'text': 'Introduc...   5933
# 1          118  {'actionDate': '2023-10-11', 'text': 'Introduc...   5932
# 2          118  {'actionDate': '2023-10-11', 'text': 'Introduc...   5931
# 3          118  {'actionDate': '2023-10-11', 'text': 'Introduc...   5930
# 4          118  {'actionDate': '2023-10-11', 'text': 'Introduc...   5929
# ...        ...                                                ...    ...
# 1245       118  {'actionDate': '2023-07-27', 'text': 'Subcommi...   2950
# 1246       118  {'actionDate': '2023-07-27', 'text': 'Subcommi...   1792
# 1247       118  {'actionDate': '2023-07-27', 'text': 'Subcommi...   1437
# 1248       118  {'actionDate': '2023-07-26', 'text': 'Became P...   1096
# 1249       118  {'actionDate': '2023-07-26', 'text': 'Received...   1684
#
#      originChamber originChamberCode  \
# 0            House                 H
# 1            House                 H
# 2            House                 H
# 3            House                 H
# 4            House                 H
# ...            ...               ...
# 1245         House                 H
# 1246         House                 H
# 1247         House                 H
# 1248         House                 H
# 1249         House                 H
#
#                                                   title type  updateDate  \
# 0     To amend the Higher Education Act of 1965 to r...   HR  2023-10-12
# 1     To authorize additional assistance to Israel u...   HR  2023-10-12
# 2     To require a briefing from a senior official o...   HR  2023-10-12
# 3     To amend title 5, United States Code, to requi...   HR  2023-10-12
# 4     To amend section 6906 of title 31, United Stat...   HR  2023-10-12
# ...                                                 ...  ...         ...
# 1245           Coastal Habitat Conservation Act of 2023   HR  2023-10-04
# 1246              South Pacific Tuna Treaty Act of 2023   HR  2023-10-04
# 1247                   Black Vulture Relief Act of 2023   HR  2023-10-04
# 1248  250th Anniversary of the United States Marine ...   HR  2023-10-04
# 1249  Haiti Criminal Collusion Transparency Act of 2023   HR  2023-10-04
#
#      updateDateIncludingText  \
# 0       2023-10-12T07:16:04Z
# 1       2023-10-12T07:16:04Z
# 2       2023-10-12T07:16:04Z
# 3       2023-10-12T07:16:04Z
# 4       2023-10-12T07:16:04Z
# ...                      ...
# 1245    2023-10-04T13:24:20Z
# 1246    2023-10-04T13:52:55Z
# 1247    2023-10-04T13:24:20Z
# 1248    2023-10-04T13:51:28Z
# 1249    2023-10-04T13:24:20Z
#
#                                                     url
# 0     https://api.congress.gov/v3/bill/118/hr/5933?f...
# 1     https://api.congress.gov/v3/bill/118/hr/5932?f...
# 2     https://api.congress.gov/v3/bill/118/hr/5931?f...
# 3     https://api.congress.gov/v3/bill/118/hr/5930?f...
# 4     https://api.congress.gov/v3/bill/118/hr/5929?f...
# ...                                                 ...
# 1245  https://api.congress.gov/v3/bill/118/hr/2950?f...
# 1246  https://api.congress.gov/v3/bill/118/hr/1792?f...
# 1247  https://api.congress.gov/v3/bill/118/hr/1437?f...
# 1248  https://api.congress.gov/v3/bill/118/hr/1096?f...
# 1249  https://api.congress.gov/v3/bill/118/hr/1684?f...
#
# [1250 rows x 10 columns]

# %%
root = 'https://api.congress.gov/v3'
congress = '118'
bill_type = 's'
endpoint = f'/bill/{congress}/{bill_type}'

r = requests.get('https://httpbin.org/user-agent')
useragent = json.loads(r.text)['user-agent']
headers = {'User-Agent': useragent,
              'From': 'zrc3hc@virginia.edu'}

senate_bills = []
for i in range(0, 1001, 250):
    parameters = {'format': 'json',
                 'offset': i,
                 'limit': 250,
                 'sort': 'updateDate+desc',
                 'api_key': congressapi
                 }
    r = requests.get(root + endpoint, params = parameters, headers = headers)
    myjson = json.loads(r.text)
    bills = myjson['bills']
    senate_bills.append(bills)

# %%
df1 = pd.DataFrame.from_dict(senate_bills[0])
df2 = pd.DataFrame.from_dict(senate_bills[1])
df3 = pd.DataFrame.from_dict(senate_bills[2])
df4 = pd.DataFrame.from_dict(senate_bills[3])
df5 = pd.DataFrame.from_dict(senate_bills[4])
frames = [df1, df2, df3, df4, df5]
senate_bills = pd.concat(frames, ignore_index = True)

# %%
senate_bills
# Out:
#       congress                                       latestAction number  \
# 0          118  {'actionDate': '2023-10-06', 'text': 'Became P...   2795
# 1          118  {'actionDate': '2023-10-06', 'text': 'Became P...    112
# 2          118  {'actionDate': '2023-10-04', 'text': 'Read twi...   3039
# 3          118  {'actionDate': '2023-10-04', 'text': 'Read twi...   3038
# 4          118  {'actionDate': '2023-10-04', 'text': 'Read twi...   3037
# ...        ...                                                ...    ...
# 1245       118  {'actionDate': '2023-06-14', 'actionTime': '12...    305
# 1246       118  {'actionDate': '2023-06-14', 'text': 'Read twi...   1975
# 1247       118  {'actionDate': '2023-06-14', 'text': 'Read twi...   1974
# 1248       118  {'actionDate': '2023-06-14', 'text': 'Read twi...   1970
# 1249       118  {'actionDate': '2023-06-14', 'text': 'Read twi...   1971
#
#      originChamber originChamberCode  \
# 0           Senate                 S
# 1           Senate                 S
# 2           Senate                 S
# 3           Senate                 S
# 4           Senate                 S
# ...            ...               ...
# 1245        Senate                 S
# 1246        Senate                 S
# 1247        Senate                 S
# 1248        Senate                 S
# 1249        Senate                 S
#
#                                                   title type  updateDate  \
# 0     A bill to amend title 38, United States Code, ...    S  2023-10-11
# 1     A bill to amend title 38, United States Code, ...    S  2023-10-11
# 2                Federal Kratom Consumer Protection Act    S  2023-10-07
# 3                 American Offshore Worker Fairness Act    S  2023-10-07
# 4                                              SEED Act    S  2023-10-07
# ...                                                 ...  ...         ...
# 1245  250th Anniversary of the United States Marine ...    S  2023-10-04
# 1246  Discharge Review Board Accountability Act of 2023    S  2023-10-04
# 1247  Protecting Americans' Data From Foreign Survei...    S  2023-10-04
# 1248             Informed Student Borrowing Act of 2023    S  2023-10-04
# 1249  Streamlining Accountability and Value in Educa...    S  2023-10-04
#
#      updateDateIncludingText  \
# 0       2023-10-11T21:15:13Z
# 1       2023-10-11T21:00:21Z
# 2       2023-10-07T12:15:25Z
# 3       2023-10-07T12:15:25Z
# 4       2023-10-07T12:30:39Z
# ...                      ...
# 1245    2023-10-04T13:24:20Z
# 1246    2023-10-04T14:03:11Z
# 1247    2023-10-04T14:03:11Z
# 1248    2023-10-04T14:03:10Z
# 1249    2023-10-04T14:03:10Z
#
#                                                     url
# 0     https://api.congress.gov/v3/bill/118/s/2795?fo...
# 1     https://api.congress.gov/v3/bill/118/s/112?for...
# 2     https://api.congress.gov/v3/bill/118/s/3039?fo...
# 3     https://api.congress.gov/v3/bill/118/s/3038?fo...
# 4     https://api.congress.gov/v3/bill/118/s/3037?fo...
# ...                                                 ...
# 1245  https://api.congress.gov/v3/bill/118/s/305?for...
# 1246  https://api.congress.gov/v3/bill/118/s/1975?fo...
# 1247  https://api.congress.gov/v3/bill/118/s/1974?fo...
# 1248  https://api.congress.gov/v3/bill/118/s/1970?fo...
# 1249  https://api.congress.gov/v3/bill/118/s/1971?fo...
#
# [1250 rows x 10 columns]

# %%
root = 'https://api.congress.gov/v3'
congress = '118'
bill_type = 's'
cosponsors = []

for i in range(0, 100):
    if i % 10 ==0:
        print(f"Collecting bill number {i}")
    bill_number = senate_bills.iloc[i]['number']
    endpoint = f'/bill/{congress}/{bill_type}/{bill_number}/cosponsors'
    parameters = {'format': 'json',
                 'sort': 'updateDate+desc',
                 'api_key': congressapi
    }
    r = requests.get(root + endpoint, params = parameters, headers = headers)
    myjson = json.loads(r.text)
    cosponsors = myjson['cosponsors']
    cosponsors.append({"Bill Number": f"S {bill_number}", "Cosponsors": cosponsors})
cosponsors = pd.DataFrame.from_dict(cosponsors)
cosponsors
# Out:
# Collecting bill number 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 9
#       7 if i % 10 ==0:
#       8     print(f"Collecting bill number {i}")
# ----> 9 bill_number = senate_bills.iloc[i]['number']
#      10 endpoint = f'/bill/{congress}/{bill_type}/{bill_number}/cosponsors'
#      11 parameters = {'format': 'json',
#      12              'sort': 'updateDate+desc',
#      13              'api_key': congressapi
#      14 }
#
# NameError: name 'senate_bills' is not defined

# %%
root = 'http://www.opensecrets.org/api/'
parameters = {'method': 'getLegislators',
             'apikey': opensecretsapi,
             'id': 'VA', 
             'output': 'json'}
headers = {'User-Agent': useragent,
          'From': 'zrc3hc@virginia.edu'}
r = requests.get(root, params = parameters, headers = headers)
myjson = json.loads(r.text)

r = requests.get(root, params = parameters, headers=headers)

cids = []
for i in range(0, len(myjson['response']['legislator'])):
    cid = myjson['response']['legislator'][i]['@attributes']['cid']
    cids.append(cid)
cids
# Out:
# ['N00029459',
#  'N00048315',
#  'N00002147',
#  'N00051961',
#  'N00045557',
#  'N00042296',
#  'N00041418',
#  'N00036018',
#  'N00032029',
#  'N00041002',
#  'N00029891',
#  'N00033177',
#  'N00002097']

# %%
financial_information = []
for i in range(0, len(cids)): 
    paraments = {'method': 'memPFDprofile',
                'apikey': opensecretsapi,
                'cid': cids[i],
                'output': 'json'}
    r = requests.get(root, params = parameters, headers = headers)
    myjson = json.loads(r.text)
    data = myjsons['response']['member_provile']
    financial_information = pd.Dataframe.from_dict(financial_information)
    financial_information
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 9
#       7 r = requests.get(root, params = parameters, headers = headers)
#       8 myjson = json.loads(r.text)
# ----> 9 data = myjsons['response']['member_provile']
#      10 financial_information = pd.Dataframe.from_dict(financial_information)
#      11 financial_information
#
# NameError: name 'myjsons' is not defined
